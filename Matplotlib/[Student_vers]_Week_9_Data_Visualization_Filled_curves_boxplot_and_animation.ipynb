# %% [markdown]
# # <center> Visualization with Python: Filled Curves, Boxplot and Animation</center>
#
# This course is devoted to student of Undergraduate Student of Informatics, Telkom University.
#
# Detail of Course
#
#
# *   Course Name: (CSH4W3) Data Visualization
#
# *   Lecturer: Dr. Putu Harry Gunawan
#
#
# ---

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. How to define a variabels which consists of integer, float and string value?

# %%
a = 2
b = 0.85
c = 'Hello world'

print(a)
print(b)
print(c)
# Out:
# 2
# 0.85
# Hello world

# %% [markdown]
# 2. How to make an array which has elements dog, cat, snail, snake, rabbit and bird? and how to get the first element and the last element

# %%
Array = ['dog', 'cat', 'snail', 'rabbit', 'bird']

print(Array)
print('First element:', Array[0])
print('Last element:', Array[-1])
# Out:
# ['dog', 'cat', 'snail', 'rabbit', 'bird']
# First element: dog
# Last element: bird

# %% [markdown]
# **NumPy**
#
# 3. How to make an array size 100 which consits of float number in [0,10]?

# %%
import numpy as np

Array = np.linspace(0, 10, 100)

print(Array)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %% [markdown]
# 4. Please create a random array size (5, 5) where the element is in [0,1]

# %%
# Create an array with random values 
e = np.random.random((5, 5))
print ("\nA random array:\n", e)
# Out:
# A random array:
#  [[0.26376585 0.6213971  0.09009675 0.16995621 0.07086841]
#  [0.8840792  0.91384386 0.76151561 0.56165075 0.75673618]
#  [0.09973438 0.30056431 0.54972788 0.57360801 0.37721617]
#  [0.58947069 0.89960658 0.96251384 0.30096892 0.41556783]
#  [0.5774515  0.1747718  0.10287579 0.02742472 0.58929292]]

# %% [markdown]
# 5. Please define a function $\sin(\pi x) + x$ and print the result with $x=0.5$

# %%
def Sin(x):
    return np.sin(np.pi * x) + x

print(Sin(0.5))
# Out:
# 1.5

# %% [markdown]
# 6. Plot a function $\sin(x) + \cos(x) $ where $x \in [0,4\pi]$ complete wuth legend etc

# %%
import matplotlib.pyplot as plt
import numpy as np

def fungsi1(x):
    return np.sin(x) + np.cos(x)

x = np.linspace(0, 4*np.pi, 100)

plt.xlabel('x')
plt.ylabel('y')

plt.grid()

plt.plot(x, fungsi1(x), color='red', linewidth=3)

plt.legend(('sin(x) + cos(x)',), loc='upper right')
plt.title('Plot sin(x) + cos(x)', fontsize=20)
plt.show()

# %% [markdown]
# # Filled Curves

# %% [markdown]
# In this section, the filled curves plot will be elaborated.

# %% [markdown]
# First: Plot $\sin(2 \pi x)$ where $x\in [0,2]$

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2, 100)
y = np.sin(2*np.pi*x)

plt.xlabel('x')
plt.ylabel('y')

plt.grid()

plt.plot(x, y, color='red', linewidth=3)

plt.show()

# %% [markdown]
# To filled the curve with color from 0 to line of $\sin(2 \pi x)$, the use plt.fill_between(x, 0, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y = np.sin(2*np.pi*x)

plt.xlabel('x')
plt.ylabel('y')

plt.xlim(min(x)-0.1, max(x)+0.1)
plt.ylim(min(y)-0.1, max(y)+0.1)

plt.grid()

plt.plot(x, y, color='red', linewidth=3)
plt.fill_between(x, 0, y)

plt.show()

# %% [markdown]
# To filled the curve with color above the curve sin

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y = np.sin(2*np.pi*x)

plt.xlabel('x')
plt.ylabel('y')

plt.xlim(min(x)-0.1, max(x)+0.1)
plt.ylim(min(y)-0.1, max(y)+0.1)

plt.grid()

plt.plot(x, y, color='red', linewidth=3)
plt.fill_between(x, 2, y)

plt.show()

# %% [markdown]
# To filled the curve with color bellow the curve sin

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y = np.sin(2*np.pi*x)

plt.xlabel('x')
plt.ylabel('y')

plt.xlim(min(x)-0.1, max(x)+0.1)
plt.ylim(min(y)-0.1, max(y)+0.1)

plt.grid()

plt.plot(x, y, color='red', linewidth=3)
plt.fill_between(x, -2, y)

plt.show()

# %% [markdown]
# To filled the curve with color between two curves, use the following syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2*np.pi*x)
y2 = np.cos(2*np.pi*x)

plt.xlabel('x')
plt.ylabel('y')

plt.xlim(min(x)-0.1, max(x)+0.1)
plt.ylim(min(y1)-0.1, max(y1)+0.1)

plt.grid()

plt.plot(x, y1, color='red', linewidth=3)
plt.plot(x, y2, color='green', linewidth=3)
plt.fill_between(x, y2, y1)

plt.show()

# %% [markdown]
# To filled the curve with color between two curves, where sin > cos, use the following syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2*np.pi*x)
y2 = np.cos(2*np.pi*x)

plt.xlabel('x')
plt.ylabel('y')

plt.xlim(min(x)-0.1, max(x)+0.1)
plt.ylim(min(y1)-0.1, max(y1)+0.1)

plt.grid()

plt.plot(x, y1, color='red', linewidth=3)
plt.plot(x, y2, color='green', linewidth=3)
plt.fill_between(x, y2, y1, where=y1 >= y2)
 
plt.show()

# %% [markdown]
# To filled the curve with color between two curves, where sin > cos and masked if cos > 0, use the following syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2*np.pi*x)
y2 = np.cos(2*np.pi*x)

y2m = np.ma.masked_where(y2 > 0, y2)

plt.xlabel('x')
plt.ylabel('y')

plt.xlim(min(x)-0.1, max(x)+0.1)
plt.ylim(min(y1)-0.1, max(y1)+0.1)

plt.grid()

plt.plot(x, y1, color='red', linewidth=3)
plt.plot(x, y2m, color='green', linewidth=3)
plt.fill_between(x, y2m, y1, where=y1 >= y2m)
 
plt.show()

# %% [markdown]
# Exercise
#
# Plot the following picture, use $\sin(2 \pi x)$, $\cos( 2 \pi x)$ and $2\cos(2 \pi x)$ where $x \in [0,2]$
#
# <img src = "https://i.imgur.com/cRE5WDp.png" align = "center">

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.show()

# %% [markdown]
# # Boxplot for statistics

# %% [markdown]
# Boxplots are a standardized way of displaying the distribution of data based on a five number summary (“minimum”, first quartile (Q1), median, third quartile (Q3), and “maximum”).
#
#
# *   **median (Q2/50th Percentile)**: the middle value of the dataset.
# *   **first quartile (Q1/25th Percentile)**: the middle number between the smallest number (not the “minimum”) and the median of the dataset.
# *   **third quartile (Q3/75th Percentile)**: the middle value between the median and the highest value (not the “maximum”) of the dataset.
# *   **interquartile range (IQR)**: 25th to the 75th percentile.
# *   **whiskers** (shown in blue)
# *   **outliers** (shown as green circles)
# *   **“maximum”**: Q3 + 1.5*IQR
# *   **“minimum”**: Q1 -1.5*IQR
#
#
#
#
# <img src = "https://miro.medium.com/max/8100/1*NRlqiZGQdsIyAu0KzP7LaQ.png" width="400" height="421" align = "center">

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)
std = 1
x = np.random.normal(0, std, size=100)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)
all_data = []
for std in range(1,5):
 all_data.append(np.random.normal(0, std, size=100))

labels = ['x1', 'x2', 'x3', 'x4']

fig, axes = plt.subplots(2, 2, figsize=(6, 6))
axes[0][0].hist(all_data[0])
axes[0][1].hist(all_data[1])
axes[1][0].hist(all_data[2])
axes[1][1].hist(all_data[3])
plt.show()

# %%
labels = ['x1', 'x2', 'x3', 'x4']

plt.boxplot(all_data, vert=True, patch_artist=True, labels=labels)

plt.title('Notched box plot')
plt.show()

# %% [markdown]
# Make a boxplot using random non gaussian distribution

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random test data
np.random.seed(19680801)

data = np.random.random(100)

fig, axs = plt.subplots(1, 2, figsize=(8, 4))
axs[0].hist(data)
axs[0].set_xlabel('Data', fontsize=24)
axs[0].set_ylabel('Frequency', fontsize=24)

bp = axs[1].boxplot(data, patch_artist=True)
axs[1].set_xlabel('Data', fontsize=24)
axs[1].set_ylabel('area near', fontsize=24)
for patch in bp['boxes']:
    patch.set(facecolor='#FFFF66')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Create animation

# %% [markdown]
# In this section, example to make animation will be elaborated.
#
# <img src = "https://i.imgur.com/4tMLG3M.gif" align= "center"><img src= "https://i.imgur.com/LNYp3ZQ.gif" align ="center">

# %% [markdown]
# First create annimation gif sin(x) using FuncAnimation

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')

fig = plt.figure()
ax = plt.axes(xlim=(0, 4), ylim=(-2, 2))
ax.set_xlabel('x', fontsize=20)
ax.set_ylabel('sin(x)', fontsize=20)
ax.set_title('Animation of sin(x)', fontsize=20)
ax.grid()
line, = ax.plot([], [], color='red', linewidth=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = FuncAnimation(fig, animate, init_func=init,
                               frames=50, interval=20, blit=True)

anim.save('sin_wave.gif', writer='imagemagick')
# Out:
# MovieWriter imagemagick unavailable; trying to use <class 'matplotlib.animation.PillowWriter'> instead.

# %% [markdown]
# Another function to create animation

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import imageio

def plot_for_offset(power, y_max):
    # Data for plotting
    t = np.arange(0.0, 100, 1)
    s = t**power
    
    fig = plt.figure()
    ax = plt.axes(xlim=(-5, 105), ylim=(0, 100))
    ax.plot(t, s, color='red', linewidth=2)
    ax.grid()
    ax.set_xlabel('x', fontsize=20)
    ax.set_ylabel('x^{}'.format(power), fontsize=20)
    ax.set_title('Power of x', fontsize=20)
    
    ax.set_ylim(0, y_max)
    plt.tight_layout
    
    fig.canvas.draw()
    image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
    image = image.reshape(fig.canvas.get_width_height()[::-1] + (3,))

    return image

kwargs_write = {'fps':1.0, 'quantizer':'nq'}
imageio.mimsave('./powers.gif', [plot_for_offset(i/4, 100) for i in range(10)], fps=1)

# %% [markdown]
# **Exercise**
#
# Make animation as the followin gif, where the function is $\sin(2\pi (x-ct)$ where $t$ is time and $c$ is a wave speed, and let $c=10$.
#
# <img src="https://i.imgur.com/EeApTLS.gif" align="center">

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import imageio

def plot_for_offset(time):
    # Data for plotting
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * 10*time))
    
    fig, ax = plt.subplots(figsize=(6, 4))
    ax.fill_between(x, -3, y)
    ax.plot(x, y, color='red', linewidth=2)
    ax.grid()
    ax.set_xlabel('x', fontsize=20)
    ax.set_ylabel('sin(2 pi x)', fontsize=20)
    ax.set_title('Simulation of waves at time={}'.format(time), fontsize=20)
    
    ax.set_xlim(0, 4)
    ax.set_ylim(-2.1, 2.1)
    
    fig.canvas.draw()
    image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
    image = image.reshape(fig.canvas.get_width_height()[::-1] + (3,))

    return image

kwargs_write = {'fps':1.0, 'quantizer':'nq'}
imageio.mimsave('./waves_exercise.gif', [plot_for_offset(i) for i in range(10)], fps=1)

# %% [markdown]
# # HOMEWORK

# %% [markdown]
# Note: Beberapa library harus diinstall
# ```
# pip install mplfinance
# pip install mpl-finance
# ```

# %% [markdown]
# 1. Make an example of candlestick plot and please explain in detail

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Library yang digunakan untuk candlestick plot (terbaru), link: https://github.com/matplotlib/mplfinance
import mplfinance as mpf

# Load data yang terdapat pada backup yahoo finance, karena API dari yahoo finance sudah tidak berlaku
df = pd.read_csv('https://pythonprogramming.net/yahoo_finance_replacement', index_col = 'Date')
df.head()
# Out:
#               Open    High     Low   Close  Adjusted_close      Volume
# Date
# 2017-07-26  153.35  153.93  153.06  153.50          153.50  12778195.0
# 2017-07-25  151.80  153.84  151.80  152.74          152.74  18714400.0
# 2017-07-24  150.58  152.44  149.90  152.09          152.09  21304700.0
# 2017-07-21  149.99  150.44  148.88  150.27          150.27  26252630.0
# 2017-07-20  151.50  151.74  150.19  150.34          150.34  17243748.0

# %%
# mengubah index Date menjadi object Date, karena library mpf hanya menerima index dengan type object Date
df.index = pd.to_datetime(df.index)

# plot dengan library mpf dengan type candlestick, dan show_nontrading=True akan mengskip tanggal tidak ada tradding
mpf.plot(df[:20], type='candle', show_nontrading=True, style='yahoo')

# %% [markdown]
# 2. Make a animation of candlestick movement using (real data or random generator)

# %%
# %matplotlib notebook 

# - Import library
from mpl_finance import candlestick_ohlc
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import time

# Load data yang terdapat pada backup yahoo finance, karena API dari yahoo finance sudah tidak berlaku
df2 = pd.read_csv('https://pythonprogramming.net/yahoo_finance_replacement')
df2.head()
# Out:
# C:\Users\Iriyanto\Anaconda3\lib\site-packages\mpl_finance.py:22: DeprecationWarning:
#
# ...
#
#    WARNING: `mpl_finance` is deprecated:
#
#     Please use `mplfinance` instead (no hyphen, no underscore).
#
#     To install: `pip install --upgrade mplfinance`
#
#    For more information, see: https://pypi.org/project/mplfinance/
#
# ...
#
#   category=DeprecationWarning)
#          Date    Open    High     Low   Close  Adjusted_close      Volume
# 0  2017-07-26  153.35  153.93  153.06  153.50          153.50  12778195.0
# 1  2017-07-25  151.80  153.84  151.80  152.74          152.74  18714400.0
# 2  2017-07-24  150.58  152.44  149.90  152.09          152.09  21304700.0
# 3  2017-07-21  149.99  150.44  148.88  150.27          150.27  26252630.0
# 4  2017-07-20  151.50  151.74  150.19  150.34          150.34  17243748.0

# %%
# ambil data
df2 = df.iloc[::-1]
candlestick_data = df2[:50]

# - Inisiasi graph
fig = plt.figure(figsize=(8,5))
ax = plt.subplot2grid((1,1), (0,0))
plt.ion()

# - Iterasi data dan masukan ke chart
all_candles = range(len(candlestick_data))
for candle in all_candles:
    candles_to_show = candlestick_data[0:candle]
    ohlc_counter = range(len(candles_to_show["Open"]))
    ohlc = []
    for ohlc_item in ohlc_counter:
        append_me = ohlc_counter[ohlc_item], \
                    candles_to_show.iloc[ohlc_item]["Open"], \
                    candles_to_show.iloc[ohlc_item]["High"],  \
                    candles_to_show.iloc[ohlc_item]["Low"], \
                    candles_to_show.iloc[ohlc_item]["Close"]
        ohlc.append(append_me)
        
    ax.clear() # - Clear chart yang sudah ada
    candlestick_ohlc(ax, ohlc, width=0.4, 
                     colorup='#075105', 
                     colordown='#AF141A')
    
    for label in ax.xaxis.get_ticklabels():
        label.set_rotation(45)
        
    ax.xaxis.set_major_locator(mticker.MaxNLocator(10))
    ax.grid(True)
    
    plt.grid(True)
    plt.xlabel('Candle count')
    plt.ylabel('Price')
    plt.title('Candlestick chart')
    plt.subplots_adjust(left=0.09, bottom=0.20, right=0.94, 
                        top=0.90, wspace=0.2, hspace=0)
    
    fig.canvas.draw() # - Draw chart baru
    time.sleep(0.5) # - Waktu tunggu untuk setiap data
# Out:
# <img src="data:image/png;base64,..." width="800">
