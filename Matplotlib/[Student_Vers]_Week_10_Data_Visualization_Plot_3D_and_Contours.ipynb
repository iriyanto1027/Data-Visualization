# %% [markdown]
# # <center> Visualization with Python: 3D plot and contour</center>
#
# This course is devoted to student of Undergraduate Student of Informatics, Telkom University.
#
# Detail of Course
#
#
# *   Course Name: (CSH4W3) Data Visualization
#
# *   Lecturer: Dr. Putu Harry Gunawan
#
# *   Student: Iriyanto - 1301174295
#
# ---
#
# One of useful toolkit to visualize dataset in 3D provided by Matplotlib is **mplot3D**.
# The mplot3d toolkit adds simple 3D plotting capabilities to matplotlib by supplying an axes object that can create a 2D projection of a 3D scene. The resulting graph will have the same look and feel as regular 2D plots.
# The interactive backends also provide the ability to rotate and zoom the 3D scene. One can rotate the 3D scene by simply clicking-and-dragging the scene. Zooming is done by right-clicking the scene and dragging the mouse up and down. Note that one does not use the zoom button like one would use for regular 2D plots.

# %% [markdown]
# ### 3D Line plots / Parametric Curve
# Suppose that we want to plot a parametric curve in 3D defined by a parametric function :
#
# $(x(s), y(s)) = (\sin{s}, \cos{s}), \, \text{for } s=[1,15]$

# %%
from mpl_toolkits import mplot3d  
import matplotlib.pyplot as plt
import numpy as np

# %%
# Set the object axes for 3D plot
fig = plt.figure()
ax = plt.axes(projection='3d')

# Create data for a three-dimensional line
s = np.linspace(0, 15, 1000)
x = np.sin(s)
y = np.cos(s)
ax.plot3D(x, y, s, 'blue', linewidth=3)
plt.show()

# %% [markdown]
# Exercise:
#
# Please make plot as the following image
#
# <img src="https://i.imgur.com/moBUJnm.png" align="center">

# %%
# Set the object axes for 3D plot
fig = plt.figure()
ax = plt.axes(projection='3d')

# Create data for a three-dimensional line
s = np.linspace(1, 15, 1000)
x = np.sin(s)
y = np.cos(s)
ax.plot3D(x, y, s, 'blue', linewidth=3)
ax.scatter3D(np.sin(0), np.cos(0), 0, color='red', linewidth=3)
ax.scatter3D(np.sin(15), np.cos(15), 15, color='red', linewidth=3)
plt.show()

# %% [markdown]
# ## 3D Scatter plots

# %%
# Set the object axes for 3D plot
fig = plt.figure()
ax = plt.axes(projection='3d')


z = 15 * np.random.random(100)
x = np.sin(z) + 0.1 * np.random.random(100)
y = np.cos(z) + 0.1 * np.random.random(100)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Scatter plot set of points (z,x,y)$\in \mathbb{R}^3$')
plt.tight_layout()
ax.scatter3D(x, y, z, c=z, cmap='Greens');

# %% [markdown]
# Bold color

# %%
# Set the object axes for 3D plot
fig = plt.figure()
ax = plt.axes(projection='3d')

z = 15 * np.random.random(100)
x = np.sin(z) + 0.1 * np.random.random(100)
y = np.cos(z) + 0.1 * np.random.random(100)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_title('Scatter plot set of points (z,x,y)$\in \mathbb{R}^3$')

ax.scatter3D(x, y, z, color='green');

# %% [markdown]
# ## Surface plots with wireframe
#
# ***Wireframe*** plot takes a grid of values and projects it onto the specified three-dimensional surface, and can make the resulting three-dimensional forms quite easy to visualize. It is resulting a very simple surface look.
#
# Suppose we want to plot a surface from 2 dimensional real valued function,   $ f:\mathbb{R}^2 \rightarrow \mathbb{R}$, defined as:
#
# $f(x,y) = \sin(x)^2 + \cos(10 + y) \cos(x)$  for $(x,y) \in [-3,3] \times [-3,3]$

# %%
def f(x, y):
    return np.sin(x)**2 + np.cos(10+y) * np.cos(x)

#create an object figure and axes. 
fig = plt.figure(figsize=(8, 6))
ax = plt.axes(projection='3d')

# Generating data points (X,Y) using meshgrid and compute f(X,Y)=Z, such that 
# we have 3D data points (X,Y,Z) to create the surface of function f(x,y). 
x = np.linspace(-3, 3, 20)
y = np.linspace(-3, 3, 20)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)


# Plot a basic wireframe by using 'plot_wireframe'
ax.plot_wireframe(X, Y, Z, rstride=1, cstride=1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Wireframe surface of Z = $f(x,y) = \sin(x)^2 + \cos(10 + y) \cos(x)$')
plt.show()

# %% [markdown]
# ## Smooth Surface plots
#
# Example make a surface plot
#
# $f(x,y)=\sin(\sqrt{x^2 +y^2})$ on $[-6,6] \times [-6,6]$

# %%
def f(x, y):
    return np.sin(np.sqrt(x**2 + y**2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

fig = plt.figure()

# Generating data points (X,Y) using meshgrid and compute f(X,Y)=Z, such that 
# we have 3D data points (X,Y,Z) to create the surface of function f(x,y). 
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Create axes object and plot the surface using "plot_surface". 
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('surface Z = f(X,Y)=$\sin\sqrt{x^2 + y^2}$');

# %%
## Rotate 
ax.view_init(60, 35)
fig

# %% [markdown]
# ## Histogram pair of data (x,y)
#
# I can be visualized as 2D plot eqquiped by color map inform the frequency, as below.

# %%
#2D Histogram
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)
N_points = 100000
n_bins = 20

# Generate a normal distribution, center at x=0 and y=5
x = np.random.randn(N_points)
y = .4 * x + np.random.randn(N_points) + 5


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
hist, xedges, yedges = np.histogram2d(x, y, bins=16, range=[[-4, 4], [0, 10]])

# Construct arrays for the anchor positions of the 16 bars.
xpos, ypos = np.meshgrid(xedges[:-1] + 0.25, yedges[:-1] + 0.25, indexing="ij")
xpos = xpos.ravel()
ypos = ypos.ravel()
zpos = 0

# Construct arrays with the dimensions for the 16 bars.
dx = dy = 0.5 * np.ones_like(zpos)
dz = hist.ravel()

ax.bar3d(xpos, ypos, zpos, dx, dy, dz, zsort='average')

plt.show()

# %% [markdown]
# ***Or*** with 3D histogram as showed below.

# %%
fig, axs = plt.subplots(figsize=(5, 5), sharex=True, sharey=True,
                        tight_layout=True)

# We can increase the number of bins on each axis
counts, xedges, yedges, im= axs.hist2d(x, y, bins=30)
plt.colorbar(im, ax=axs)
plt.show()

# %% [markdown]
# ## Contour Plots
# Suppose that given a function:
# f(x,y) = z = $2 \left(e^{-x^2 - y^2} - e^{-(x-1)^2 - (y-1))^2} \right)$.
#
# We want to visualize the contour / levelset of the function.

# %%
# contour PLot library
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
# preparing 3D data points using 'meshgrid'
delta = 0.025
x = np.arange(-3, 3, delta)
y = np.arange(-3, 3, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X-2)**2 - (Y-1)**2)
Z = (Z1 - Z2) * 2

# controling line
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
ax.set_title('Contour plot of f(x,y) = $2 (e^{-x^2 - y^2} - e^{-(x-1)^2 - (y-1))^2} )$')
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.show()

# %%
# controling line
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z, 6,
                 linewidths=np.arange(.5, 4, .5),
                 colors=('r', 'green', 'blue', (1, 1, 0), '#afeeee', '0.5')
                 )
ax.clabel(CS, fontsize=9, inline=1)
ax.set_title('Contour plot of f(x,y) = $2 e^{-x^2 - y^2} - e^{-(x-1)^2 - (y-1))^2}$')
ax.set_xlabel('X')
ax.set_ylabel('Y')
plt.show()

# %% [markdown]
# **Another Example**
#
# We want to visualize the contour / levelset of the function.
#
# $f(x,y) = \sin(x)^2 + \cos(10 + y) \cos(x)$  for $(x,y) \in [-3,3] \times [-3,3]$
#
# The plot in the right side is a nice contour plot using funcion ***contour***, but the spaces between the lines may be a bit distracting.
# Also, it is possible to plot filled contour plot using ***contourf()*** and add the colorbar that is automatically generated by function ***colorbar()***.

# %%
# contour PLot library
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# preparing 3D data points using 'meshgrid'. The smoothness depends on delta. 
delta = 0.0025
x = np.arange(-3, 3, delta)
y = np.arange(-3, 3, delta)
X, Y = np.meshgrid(x, y)
Z = np.sin(X)**2 + np.cos(10+Y) * np.cos(X)

# create the object subplot consist 1x2 plots. 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,4))

# controling line of levelset for the left plot in the figure
CS = ax1.contour(X, Y, Z, 20,
                 linewidths=np.arange(.5, 4, .5),
                 cmap='RdGy'
                 )
ax1.clabel(CS, fontsize=9, inline=1)
ax1.set_title('Contour plot with contour level lie in the levelset')
ax1.set_xlabel('X')
ax1.set_ylabel('Y')

#create a filled contour plot using contourf equipped with the colorbar.
cs = ax2.contourf(X, Y, Z, 20, cmap='RdGy')
fig.colorbar(cs)
ax2.set_title('Filled contour plot with the colorbar')
# Out:
# Text(0.5, 1.0, 'Filled contour plot with the colorbar')

# %% [markdown]
# Exercise:
#
# Make an annimation of 3D waves
#
# $A(x,y,t) = A_0\left( \sin \left(2\pi \left(\frac{x}{\lambda} - \frac{t}{T} \right) \right) + \sin \left(2\pi \left(\frac{y}{\lambda} - \frac{t}{T}  \right)  \right) \right)$
#
# where
#
#
#
# *   $A_0=1$, $\lambda=100$, T=60
# *   on Domain $([0,200] \times [0,200])$ and Simulation time $10 \times T$
# *   $Nx=Ny=500$ dan time step =$200$
#
# <img src="https://i.imgur.com/PJlJi7n.gif" align="center">

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import imageio
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# preparing 3D data points using 'meshgrid'
delta = 1
x = np.arange(0, 200.0, delta)
y = np.arange(0, 200.0, delta)
X, Y = np.meshgrid(x, y)

T= 60
L= 100
A0= 1
dt= T*10/200

def plot_for_offset(ix):
    
    #ax.set_ylabel('x^{}'.format(power), fontsize=20)
  
    Z = A0 * (np.sin(2*np.pi * (X/L - (ix*dt)/T)) + np.sin(2*np.pi * (Y/L - (ix*dt)/T)))

    # controling line
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis', edgecolor='none')
    ax.set_title('Wave motion at time {}'.format(ix*dt))
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    
    #ax.set(xlabel='X', ylabel='x^{}'.format(power), title='Powers of x')

    # IMPORTANT ANIMATION CODE HERE
    # Used to keep the limits constant
    #ax.set_ylim(0, y_max)
    plt.tight_layout()
    # Used to return the plot as an image rray
    fig.canvas.draw()       # draw the canvas, cache the renderer
    image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')
    image  = image.reshape(fig.canvas.get_width_height()[::-1] + (3,))

    return image

kwargs_write = {'fps':1.0, 'quantizer':'nq'}
imageio.mimsave('./3Dmovie.gif', [plot_for_offset(i) for i in range(11)], fps=1)
